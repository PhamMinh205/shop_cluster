# %%
transactions = pd.read_csv("data/transactions.csv")
rules = pd.read_csv("data/rules.csv")
# Out:
# The kernel failed to start as the Python Environment 'miniconda3 (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
clusterer = RuleBasedCustomerClusterer(transactions, rules)
clusterer.build_rule_feature_matrix(...)
clusterer.build_final_features(...)

# %%
k_range = range(2, 11)
silhouette_scores = clusterer.choose_k_by_silhouette(k_range)

plt.figure(figsize=(6,4))
plt.plot(
    list(silhouette_scores.keys()),
    list(silhouette_scores.values()),
    marker='o'
)
plt.xlabel("Number of clusters (K)")
plt.ylabel("Silhouette score")
plt.title("Silhouette score vs Number of clusters")
plt.grid(True)
plt.show()

# %%
clusterer.fit_kmeans(k=4)

# %%
X_2d = clusterer.project_2d()

plt.figure(figsize=(6,5))
plt.scatter(
    X_2d[:, 0],
    X_2d[:, 1],
    c=labels,
    s=40
)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("Customer Clusters (PCA Projection)")
plt.show()

# %%
feature_configs = [
    "Rule-only (binary)",
    "Rule-weighted",
    "Rule + RFM"
]

silhouette_values = [
    0.32,  # thay bằng kết quả thật 
    0.41,
    0.46
]

plt.figure(figsize=(6,4))
plt.bar(feature_configs, silhouette_values)
plt.ylabel("Silhouette score")
plt.title("Comparison of feature configurations")
plt.show()

# %%
clusterer.profile_clusters()
